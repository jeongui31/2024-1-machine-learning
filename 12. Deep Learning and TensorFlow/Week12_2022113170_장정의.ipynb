# %% [markdown]
# # Week12: Deep Learning and TensorFlow

# %% [markdown]
# - **Student ID** : 2022113170
# - **Name** : 장정의

# %% [markdown]
# - Write and run the code below (including Quiz) in jupyter notebook
# - After completion, rename the file, and summit the file to e-class
# - Submit file name : **“Week12_\<StudentID\>_\<Name\>.ipynb”**
#   - Ex) Week12\_2020123456\_홍길동.ipynb
# - Due : **Saturday 11:59pm**
# - Library version requirements :
#   - Python version: 3.12.2
#   - TensorFlow version : 2.16.0
#   - Numpy version : 1.26.4
#   - Matplotlib version : 3.8.4
#   - Sklearn version : 1.4.2
# - Additional Installation
#   - Pydot
#     - Use `pip install pydot` for installation
#   - GraphViz
#     - If you're using conda, use `conda install graphviz`
#     - If you're not using conda, read installation instructions from [here](https://graphviz.org/download/)

# %% [markdown]
# # 1. Tensorflow Basic

# %% [markdown]
# ## Tensor
# - Tensor is like a multidimensional array
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf

# rank 0 tensor 2
a = tf.constant(2)
print(a)

# rank 1 tensor [1, 2]
a = tf.constant([1,2])
print(a)

# rank 2 tensor [[1, 2, 3], [4, 5, 6]]
a = tf.constant([[1, 2, 3], [4, 5, 6]])
print(a)
# Out:
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor([1 2], shape=(2,), dtype=int32)
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)

# %%
# tensor a to numpy array
a.numpy()
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)

# %%
# type, rank, shape, size of a
print("Type:", a.dtype)
print("Rank:", a.ndim)
print("Shape:", a.shape)
print("Size:", tf.size(a).numpy())
# Out:
# Type: <dtype: 'int32'>
# Rank: 2
# Shape: (2, 3)
# Size: 6

# %% [markdown]
# ## Operations

# %%
a = tf.constant([[1, 2],
                 [3, 4]])
b = tf.constant([[2, 2],
                 [2, 2]])

# element-wise operations on tensors, a + b, a * b
print(a+b, "\n")
print(a*b, "\n")
# Out:
# tf.Tensor(
# [[3 4]
#  [5 6]], shape=(2, 2), dtype=int32)
#
# tf.Tensor(
# [[2 4]
#  [6 8]], shape=(2, 2), dtype=int32)

# %%
# matrix multiplication on tensors, a @ b
print(tf.matmul(a,b))
print(a@b, "\n")
# Out:
# tf.Tensor(
# [[ 6  6]
#  [14 14]], shape=(2, 2), dtype=int32)
# tf.Tensor(
# [[ 6  6]
#  [14 14]], shape=(2, 2), dtype=int32)

# %%
a = tf.constant([[1, 2, 3],
                 [4, 5, 6]], dtype=tf.float32)

# reduce operations on tensors - sum, max
print(tf.reduce_sum(a))
print(tf.reduce_max(a))

# reduce operations on axis 0 - sum, mean
print(tf.reduce_sum(a, axis=0))
print(tf.reduce_mean(a, axis=0))
# Out:
# tf.Tensor(21.0, shape=(), dtype=float32)
# tf.Tensor(6.0, shape=(), dtype=float32)
# tf.Tensor([5. 7. 9.], shape=(3,), dtype=float32)
# tf.Tensor([2.5 3.5 4.5], shape=(3,), dtype=float32)

# %%
a = tf.constant([[1, 2, 3],
                 [4, 5, 6]], dtype=tf.float32)
b = tf.constant([[1, 1, 1]], dtype=tf.float32)

# broadcasting a + b
print(a+b)
# Out:
# tf.Tensor(
# [[2. 3. 4.]
#  [5. 6. 7.]], shape=(2, 3), dtype=float32)

# %% [markdown]
# ## Variables
# - a tensor whose value can be changed by running ops on it. store model parameters such as w and b

# %%
# variable x with initial value [[1, 2], [3, 4]]
w = tf.Variable([[1,2], [3,4]])

# compute tensor w + 1
w = w+1
print(w)
# Out:
# tf.Tensor(
# [[2 3]
#  [4 5]], shape=(2, 2), dtype=int32)

# %% [markdown]
# ## Automatic differentiation
# - **GradientTape** : For automatic differentiation, TensorFlow needs to remember what operations happen in what order during the forward pass.
# - Then, during the backward pass, TensorFlow traverses this list of operations in reverse order to compute gradients.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# variable with initial value 3.0
x = tf.Variable(3.0)

# record operations on tape
with tf.GradientTape() as tape:
    y = x**2

# compute dy/dx
dy_dx = tape.gradient(y, x)

print(dy_dx.numpy())
# Out:
# 6.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# variables with initial value 1s and 0s
w = tf.Variable(tf.ones((3, 2), dtype = tf.float32), name='w')
b = tf.Variable(tf.zeros((1, 2), dtype = tf.float32), name='b')

x = tf.constant([[1., 2., 3.]])
y = tf.constant([[4., 8.]])

print("w:\n", w.numpy())
print("b:\n", b.numpy())

# record operations on tape
with tf.GradientTape(persistent = True) as tape:
    y_hat = x @ w + b
    loss = tf.reduce_mean((y_hat - y) ** 2)

# compute gradients using tape.gradient()
[dl_dw, dl_db] = tape.gradient(loss, [w,b])

print("y:\n", y.numpy())
print("y_hat:\n", y_hat.numpy())
print("loss:\n", loss.numpy(), "\n")

print("dL/dw:\n", dl_dw.numpy())
print("dL/db:\n", dl_db.numpy())
# Out:
# w:
#  [[1. 1.]
#  [1. 1.]
#  [1. 1.]]
# b:
#  [[0. 0.]]
# y:
#  [[4. 8.]]
# y_hat:
#  [[6. 6.]]
# loss:
#  4.0
#
# dL/dw:
#  [[ 2. -2.]
#  [ 4. -4.]
#  [ 6. -6.]]
# dL/db:
#  [[ 2. -2.]]

# %% [markdown]
# ### Using optimizer

# %%
# variables with initial value 1s and 0s
w = tf.Variable(tf.ones((3, 2), dtype=tf.float32), name='w')
b = tf.Variable(tf.zeros((1, 2), dtype=tf.float32), name='b')

x = tf.constant([[1., 2., 3.]])
y = tf.constant([[4., 8.]])

print("w:\n", w.numpy())
print("b:\n", b.numpy())

# the loss function
def loss():
    y_hat = x @ w + b
    l = tf.reduce_mean((y_hat - y)**2)
    return l

# use an optimizer SGD
opt = tf.keras.optimizers.SGD(learning_rate=0.1)

# Manual optimization step
with tf.GradientTape() as tape:
    l = loss()

# compute gradients
grads = tape.gradient(l, [w,b])

# apply 1 step of gradient using optimizer
opt.apply_gradients(zip(grads, [w,b]))

print("w:\n", w.numpy())
print("b:\n", b.numpy())
# Out:
# w:
#  [[1. 1.]
#  [1. 1.]
#  [1. 1.]]
# b:
#  [[0. 0.]]
# w:
#  [[0.8        1.2       ]
#  [0.6        1.4       ]
#  [0.39999998 1.6       ]]
# b:
#  [[-0.2  0.2]]

# %% [markdown]
# # 2. Keras : Sequential API

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of building a sequential model 1

# %%
# create sequential model by using add()
# 7 inputs, 1 dense(fully connected) layer with 5 neurons, activation is sigmoid
# 1 dense(fully connected) layer with 4 neurons, activation is sigmoid
model = keras.Sequential()

model.add(keras.Input(shape=(7,)))
model.add(layers.Dense(5, activation='sigmoid'))
model.add(layers.Dense(4, activation='sigmoid'))

# %%
# display the model
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_34 (Dense)            (None, 5)                 40
#
#  dense_35 (Dense)            (None, 4)                 24
#
# =================================================================
# Total params: 64 (256.00 Byte)
# Trainable params: 64 (256.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Example of building a sequential model 2

# %%
# create same sequential model, by providing list of layers
model = keras.Sequential(
    [
        keras.Input(shape=(7,)),
        layers.Dense(5, activation='sigmoid'),
        layers.Dense(4, activation='sigmoid')
    ]
)

# %%
# display the model
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 5)                 40
#
#  dense_37 (Dense)            (None, 4)                 24
#
# =================================================================
# Total params: 64 (256.00 Byte)
# Trainable params: 64 (256.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot the model structure
tf.keras.utils.plot_model(model)

# %% [markdown]
# ### Example: XOR style dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

tf.random.set_seed(1)
np.random.seed(1)

# generate random x in [-1, 1]
x = np.random.uniform(low=-1, high=1, size=(100, 2))

# y is 1 if x is in 1st and 3rd quadrant
y = np.ones(len(x))
y[x[:, 0] * x[:, 1] < 0] = 0

fig = plt.figure(figsize=(6, 6))
plt.plot(x[y==0, 0], x[y==0, 1], 'o', color='red')
plt.plot(x[y==1, 0], x[y==1, 1], 'x', color='blue')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# ### Build the model using Keras

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tf.random.set_seed(1)

# create the model structure. 4 layers with units 4, 4, 4, 1. use activation ReLU and Sigmoid

model = keras.Sequential()
model.add(layers.Dense(units=4, input_shape=(2,), activation='relu'))
model.add(layers.Dense(units=4, activation='relu'))
model.add(layers.Dense(units=4, activation='relu'))
model.add(layers.Dense(units=1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_38 (Dense)            (None, 4)                 12
#
#  dense_39 (Dense)            (None, 4)                 20
#
#  dense_40 (Dense)            (None, 4)                 20
#
#  dense_41 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 57 (228.00 Byte)
# Trainable params: 57 (228.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
# compile. use optimizer SGD, loss BinaryCrossentropy
model.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.BinaryCrossentropy())

# %% [markdown]
# ### Train the model

# %%
# train the model with x, y
hist = model.fit(x, y, epochs=200, batch_size=2, verbose=1)

history = hist.history
# Out:
# Epoch 1/200
# 50/50 [==============================] - 1s 3ms/step - loss: 0.6925
# Epoch 2/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6905
# Epoch 3/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6895
# Epoch 4/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6890
# Epoch 5/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6882
# Epoch 6/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6876
# Epoch 7/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6867
# Epoch 8/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6864
# Epoch 9/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6858
# Epoch 10/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6853
# Epoch 11/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6844
# Epoch 12/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6835
# Epoch 13/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6832
# Epoch 14/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6822
# Epoch 15/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6817
# Epoch 16/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6805
# Epoch 17/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6797
# Epoch 18/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6794
# Epoch 19/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6781
# Epoch 20/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6773
# Epoch 21/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6762
# Epoch 22/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6752
# Epoch 23/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6742
# Epoch 24/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6727
# Epoch 25/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6716
# Epoch 26/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6703
# Epoch 27/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6690
# Epoch 28/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6674
# Epoch 29/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6655
# Epoch 30/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6638
# Epoch 31/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6619
# Epoch 32/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6599
# Epoch 33/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6576
# Epoch 34/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6555
# Epoch 35/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6529
# Epoch 36/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6503
# Epoch 37/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6473
# Epoch 38/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.
200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0568
# Epoch 164/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0520
# Epoch 165/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0517
# Epoch 166/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0527
# Epoch 167/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0530
# Epoch 168/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0490
# Epoch 169/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0503
# Epoch 170/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0515
# Epoch 171/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0487
# Epoch 172/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0491
# Epoch 173/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0460
# Epoch 174/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0476
# Epoch 175/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0463
# Epoch 176/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0444
# Epoch 177/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0454
# Epoch 178/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0450
# Epoch 179/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0447
# Epoch 180/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0429
# Epoch 181/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0428
# Epoch 182/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0422
# Epoch 183/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0410
# Epoch 184/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0399
# Epoch 185/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0423
# Epoch 186/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0389
# Epoch 187/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0412
# Epoch 188/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0383
# Epoch 189/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0386
# Epoch 190/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0374
# Epoch 191/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0378
# Epoch 192/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0361
# Epoch 193/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0381
# Epoch 194/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0380
# Epoch 195/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0368
# Epoch 196/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0367
# Epoch 197/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0354
# Epoch 198/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0365
# Epoch 199/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0342
# Epoch 200/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0343

# %%
# show weights of first layer
model.layers[0].get_weights()
# Out:
# [array([[ 0.6437682 , -1.8819413 , -0.24883612,  1.2306496 ],
#         [-1.0341752 , -0.02308903, -2.3645794 ,  0.2910079 ]],
#        dtype=float32),
#  array([0.08595002, 0.31096005, 0.31969914, 0.37991026], dtype=float32)]

# %%
# plot the cost. use history.history['loss']
plt.plot(range(1, len(history['loss']) + 1), history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Training Cost')

plt.show()

# %% [markdown]
# ### Plot the decision boundary

# %%
# A function for plotting decision regions
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

def plot_decision_regions(X, y, classifier, resolution=0.02):

    # setup marker generator and color map
    markers = ('o', 'x', 's', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, c=colors[idx], marker=markers[idx], label=cl)

# %%
# plot decision boundary of the model
plot_decision_regions(x, y, classifier=model)

plt.xlabel('x1')
plt.ylabel('x2')
plt.legend(loc='upper left')
plt.show()
# Out:
# 1238/1238 [==============================] - 2s 2ms/step

# %% [markdown]
# ## Saving and loading the model

# %%
# save the model
model.save('my_model.keras')

# %%
# create a model with same structure
new_model = tf.keras.models.load_model('my_model.keras')

new_x = [0.8, 0.8]
y_hat = new_model.predict([new_x])
print(y_hat)
# Out:
# 1/1 [==============================] - 0s 70ms/step
# [[0.9903529]]

# %% [markdown]
# ---

# %% [markdown]
# # 3. Keras : Functional API
# - The Keras functional API is a way to create models that are more flexible than the tf.keras.Sequential API
# - The functional API can handle models with non-linear topology, shared layers, and even multiple inputs or outputs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of building a model with functional API

# %%
from tensorflow import keras
from tensorflow.keras import layers

# inputs with shape (7, ),
# h1 is outputs(5) of a dense layer with input 'inputs', activation is sigmoid
# outputs is outputs(4) of a dense layer with input 'h1', activation is sigmoid
inputs = keras.Input(shape=(7,))

layer1 = layers.Dense(5, activation = 'sigmoid')
h1 = layer1(inputs)

layer2 = layers.Dense(4, activation = 'sigmoid')
outputs = layer2(h1)

# create a model with inputs=inputs, outputs=outputs
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
# display the model
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 7)]               0
#
#  dense_42 (Dense)            (None, 5)                 40
#
#  dense_43 (Dense)            (None, 4)                 24
#
# =================================================================
# Total params: 64 (256.00 Byte)
# Trainable params: 64 (256.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot the model structure
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### Example of building more complex model
# ![image-2.png](attachment:image-2.png)

# %%
# input1 (2, ), input2 (5, )
inputs1 = keras.Input(shape=(2,))
inputs2 = keras.Input(shape=(5,))

# h1 is outputs(2) of a dense(fully connected) layer with input 'inputs1'
# h2 is outputs(3) of a dense(fully connected) layer with input 'inputs2'
h1 = layers.Dense(2, activation="sigmoid")(inputs1)
h2 = layers.Dense(3, activation="sigmoid")(inputs2)

# c is a concatenation of h1, h2
c = layers.concatenate([h1, h2])

# outputs1 is outputs(1) of a dense(fully connected) layer with input 'c'
# outputs2 is outputs(10) of a dense(fully connected) layer with input 'c'
outputs1 = layers.Dense(1, activation="sigmoid")(c)
outputs2 = layers.Dense(10, activation="softmax")(c)

# create model with 2 inputs and 2 outputs
model = keras.Model(inputs=[inputs1, inputs2], outputs=[outputs1, outputs2])

# %%
# display the model
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_10 (InputLayer)       [(None, 2)]                  0         []
#
#  input_11 (InputLayer)       [(None, 5)]                  0         []
#
#  dense_44 (Dense)            (None, 2)                    6         ['input_10[0][0]']
#
#  dense_45 (Dense)            (None, 3)                    18        ['input_11[0][0]']
#
#  concatenate_1 (Concatenate  (None, 5)                    0         ['dense_44[0][0]',
#  )                                                                   'dense_45[0][0]']
#
#  dense_46 (Dense)            (None, 1)                    6         ['concatenate_1[0][0]']
#
#  dense_47 (Dense)            (None, 10)                   60        ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 90 (360.00 Byte)
# Trainable params: 90 (360.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# plot the model structure
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ---

# %% [markdown]
# # 4. Image Classification using Deep NN with Keras (Sequential API)

# %% [markdown]
# ### Import TensorFlow

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and prepare the Fashion MNIST dataset

# %%
# read fashion MNIST data
fashion_mnist = tf.keras.datasets.fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train.shape
# Out:
# (60000, 28, 28)

# %%
# class labels (y_train)
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
plt.imshow(X_train[0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
# names for class labels
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# name of the class label of train data 0
class_names[y_train[0]]
# Out:
# 'Ankle boot'

# %%
# show first 25 data and label
plt.figure(figsize=(8,8))

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
# scaling X
X_train, X_test = X_train / 255.0, X_test / 255.0

# %% [markdown]
# ### Build the Deep Neural Network model using Keras

# %%
# build the DNN model with flatten input, 2 dense layers with 128 outputs with relu activation,
# 1 dense layers with 10 outputs with softmax activation
model = keras.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(10, activation = 'softmax'),
])

# display the model
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_48 (Dense)            (None, 128)               100480
#
#  dense_49 (Dense)            (None, 128)               16512
#
#  dense_50 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 118282 (462.04 KB)
# Trainable params: 118282 (462.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile and Train the model
# Choose an optimizer and loss function for training

# %%
# compile the model with adam optimizer and sparse_categorical_crossentropy loss. metric is accuracy
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
import time
# checking the execution time
start_time = time.time()

# train the model. use fit(), 20 epoch, batch size 200. record history
history = model.fit(X_train, y_train, epochs=50, batch_size=200)

print("Time : ", time.time()-start_time)
# Out:
# Epoch 1/50
# 300/300 [==============================] - 2s 3ms/step - loss: 0.5595 - accuracy: 0.8050
# Epoch 2/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.3855 - accuracy: 0.8617
# Epoch 3/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.3461 - accuracy: 0.8748
# Epoch 4/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.3215 - accuracy: 0.8827
# Epoch 5/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.3017 - accuracy: 0.8898
# Epoch 6/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2866 - accuracy: 0.8942
# Epoch 7/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2786 - accuracy: 0.8972
# Epoch 8/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2639 - accuracy: 0.9028
# Epoch 9/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2568 - accuracy: 0.9043
# Epoch 10/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2494 - accuracy: 0.9064
# Epoch 11/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2354 - accuracy: 0.9115
# Epoch 12/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2281 - accuracy: 0.9144
# Epoch 13/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2209 - accuracy: 0.9172
# Epoch 14/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2135 - accuracy: 0.9203
# Epoch 15/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2091 - accuracy: 0.9211
# Epoch 16/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1999 - accuracy: 0.9250
# Epoch 17/50
# 300/300 [==============================] - 2s 6ms/step - loss: 0.1983 - accuracy: 0.9258
# Epoch 18/50
# 300/300 [==============================] - 2s 5ms/step - loss: 0.1916 - accuracy: 0.9280
# Epoch 19/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1851 - accuracy: 0.9302
# Epoch 20/50
# 300/300 [==============================] - 1s 5ms/step - loss: 0.1804 - accuracy: 0.9324
# Epoch 21/50
# 300/300 [==============================] - 2s 5ms/step - loss: 0.1772 - accuracy: 0.9348
# Epoch 22/50
# 300/300 [==============================] - 2s 5ms/step - loss: 0.1689 - accuracy: 0.9369
# Epoch 23/50
# 300/300 [==============================] - 1s 5ms/step - loss: 0.1653 - accuracy: 0.9379
# Epoch 24/50
# 300/300 [==============================] - 2s 8ms/step - loss: 0.1600 - accuracy: 0.9388
# Epoch 25/50
# 300/300 [==============================] - 2s 7ms/step - loss: 0.1564 - accuracy: 0.9418
# Epoch 26/50
# 300/300 [==============================] - 2s 6ms/step - loss: 0.1538 - accuracy: 0.9433
# Epoch 27/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1494 - accuracy: 0.9438
# Epoch 28/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1453 - accuracy: 0.9455
# Epoch 29/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1418 - accuracy: 0.9460
# Epoch 30/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1408 - accuracy: 0.9479
# Epoch 31/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1322 - accuracy: 0.9513
# Epoch 32/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1325 - accuracy: 0.9504
# Epoch 33/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1305 - accuracy: 0.9501
# Epoch 34/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1234 - accuracy: 0.9539
# Epoch 35/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1224 - accuracy: 0.9541
# Epoch 36/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1164 - accuracy: 0.9571
# Epoch 37/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1122 - accuracy: 0.9584
# Epoch 38/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1158 - accuracy: 0.9572
# Epoch 39/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1065 - accuracy: 0.9596
# Epoch 40/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1067 - accuracy: 0.9599
# Epoch 41/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1020 - accuracy: 0.9623
# Epoch 42/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1029 - accuracy: 0.9609
# Epoch 43/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1012 - accuracy: 0.9621
# Epoch 44/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0944 - accuracy: 0.9640
# Epoch 45/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0912 - accuracy: 0.9652
# Epoch 46/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0901 - accuracy: 0.9657
# Epoch 47/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0908 - accuracy: 0.9668
# Epoch 48/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0832 - accuracy: 0.9694
# Epoch 49/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0847 - accuracy: 0.9685
# Epoch 50/50
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0838 - accuracy: 0.9687
# Time :  58.36431813240051

# %% [markdown]
# ### **[Note] Advantage of using GPU**
# - TensorFlow can process large batch sizes quickly through parallel computation using GPUs, so it is much faster than Scikit-learn

# %% [markdown]
# ### Plot the loss

# %%
# plot the loss. use history.history['loss']

plt.plot(history.epoch, history.history['loss'])

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Evaluate the model

# %%
# Train and test accuracy. use evaluate()
loss, acc = model.evaluate(X_train, y_train)
print('Train accuracy : %.4f' % acc)
loss, acc = model.evaluate(X_test, y_test)
print('Test accuracy : %.4f' % acc)
# Out:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0744 - accuracy: 0.9725
# Train accuracy : 0.9725
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4755 - accuracy: 0.8929
# Test accuracy : 0.8929

# %% [markdown]
# ### Make prediction

# %%
# get the predictions of test dataset. use predict()
predictions = model.predict(X_test)
predictions.shape
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (10000, 10)

# %%
# show the image of test data 1
plt.figure(figsize=(1, 1))
plt.imshow(X_test[1], cmap=plt.cm.binary)
plt.show()

# %%
# show the true class name and the predicted class name of test data 1
y_predict = np.argmax(predictions[1])
print('True lable = %s' % class_names[y_test[1]])
print('Predicted = %s' % class_names[y_predict])
# Out:
# True lable = Pullover
# Predicted = Pullover

# %% [markdown]
# ---

# %% [markdown]
# # Quiz 1 : Learning Nonlinear Decision Boundary
# ## Train DNN model with the moon dataset
# - Build the Deep NN model with 100 neurons in 1 hidden layer, 1 neuron in output layer using Keras sequential API
# - Use ReLU for hiden layer and sigmoid for output layer
# - Use Adam optimizer and binary cross entropy
#
# 1. Train the model up to 100 epochs with btach size 10
# 2. Plot the cost change during training
# 3. Show the decision boundary

# %% [markdown]
# ### Dataset

# %%
from sklearn.datasets import make_moons, make_circles
import matplotlib.pyplot as plt

# generate 500 moon data
X, y =  make_moons(n_samples=500, noise=0.1, random_state=0)

plt.scatter(X[y==0, 0], X[y==0, 1], c='r')
plt.scatter(X[y==1, 0], X[y==1, 1], c='b')
plt.tight_layout()

plt.show()

# %%
import tensorflow as tf
import numpy as np

tf.random.set_seed(1)

# create the model structure. 1 hidden layer with 100 units, output layer with 1 unit.
# use activation ReLU and Sigmoid. show model summary
model = keras.Sequential()
model.add(layers.Dense(100, activation='relu', input_shape=(2,)))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_56 (Dense)            (None, 100)               300
#
#  dense_57 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer='adam',
              loss='BinaryCrossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
# train the model with X, y. Up to 100 epochs, batch size 10
hist = model.fit(X, y, epochs=100, batch_size=10, verbose=1)

history = hist.history
# Out:
# Epoch 1/100
# 50/50 [==============================] - 2s 4ms/step - loss: 0.6048 - accuracy: 0.7420
# Epoch 2/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4641 - accuracy: 0.8200
# Epoch 3/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3746 - accuracy: 0.8460
# Epoch 4/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3277 - accuracy: 0.8500
# Epoch 5/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3001 - accuracy: 0.8640
# Epoch 6/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2817 - accuracy: 0.8760
# Epoch 7/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2687 - accuracy: 0.8780
# Epoch 8/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2588 - accuracy: 0.8840
# Epoch 9/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2508 - accuracy: 0.8820
# Epoch 10/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2449 - accuracy: 0.8820
# Epoch 11/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2405 - accuracy: 0.8880
# Epoch 12/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2355 - accuracy: 0.8880
# Epoch 13/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2324 - accuracy: 0.8920
# Epoch 14/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2285 - accuracy: 0.8940
# Epoch 15/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2256 - accuracy: 0.8980
# Epoch 16/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2226 - accuracy: 0.8980
# Epoch 17/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2205 - accuracy: 0.9000
# Epoch 18/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2186 - accuracy: 0.9040
# Epoch 19/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2164 - accuracy: 0.9000
# Epoch 20/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2150 - accuracy: 0.9000
# Epoch 21/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2118 - accuracy: 0.9040
# Epoch 22/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2116 - accuracy: 0.9000
# Epoch 23/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2090 - accuracy: 0.9060
# Epoch 24/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2062 - accuracy: 0.9040
# Epoch 25/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2037 - accuracy: 0.9060
# Epoch 26/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2023 - accuracy: 0.9080
# Epoch 27/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2003 - accuracy: 0.9080
# Epoch 28/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1984 - accuracy: 0.9080
# Epoch 29/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1973 - accuracy: 0.9080
# Epoch 30/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1942 - accuracy: 0.9060
# Epoch 31/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9120
# Epoch 32/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1898 - accuracy: 0.9100
# Epoch 33/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1871 - accuracy: 0.9120
# Epoch 34/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9140
# Epoch 35/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1837 - accuracy: 0.9140
# Epoch 36/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9140
# Epoch 37/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1790 - accuracy: 0.9180
# Epoch 38/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1760 - accuracy: 0.9160
# Epoch 39/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1737 - accuracy: 0.9180
# Epoch 40/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1712 - accuracy: 0.9160
# Epoch 41/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1685 - accuracy: 0.9180
# Epoch 42/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1655 - accuracy: 0.9180
# Epoch 43/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1648 - accuracy: 0.9200
# Epoch 44/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1606 - accuracy: 0.9240
# Epoch 45/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1581 - accuracy: 0.9220
# Epoch 46/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1558 - accuracy: 0.9240
# Epoch 47/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1526 - accuracy: 0.9300
# Epoch 48/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1531 - accuracy: 0.9300
# Epoch 49/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1494 - accuracy: 0.9300
# Epoch 50/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1450 - accuracy: 0.9300
# Epoch 51/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9340
# Epoch 52/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.9360
# Epoch 53/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1384 - accuracy: 0.9340
# Epoch 54/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9380
# Epoch 55/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.9420
# Epoch 56/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9440
# Epoch 57/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1280 - accuracy: 0.9480
# Epoch 58/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9420
# Epoch 59/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.9480
# Epoch 60/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9480
# Epoch 61/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9480
# Epoch 62/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9560
# Epoch 63/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1128 - accuracy: 0.9560
# Epoch 64/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9540
# Epoch 65/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1077 - accuracy: 0.9580
# Epoch 66/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1047 - accuracy: 0.9660
# Epoch 67/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1020 - accuracy: 0.9640
# Epoch 68/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.9740
# Epoch 69/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9780
# Epoch 70/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0921 - accuracy: 0.9760
# Epoch 71/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0887 - accuracy: 0.9760
# Epoch 72/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0855 - accuracy: 0.9780
# Epoch 73/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0834 - accuracy: 0.9780
# Epoch 74/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0808 - accuracy: 0.9800
# Epoch 75/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0779 - accuracy: 0.9800
# Epoch 76/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0767 - accuracy: 0.9800
# Epoch 77/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0735 - accuracy: 0.9820
# Epoch 78/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0714 - accuracy: 0.9840
# Epoch 79/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 0.9860
# Epoch 80/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9820
# Epoch 81/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0653 - accuracy: 0.9880
# Epoch 82/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0641 - accuracy: 0.9900
# Epoch 83/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9860
# Epoch 84/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0588 - accuracy: 0.9880
# Epoch 85/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9880
# Epoch 86/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0558 - accuracy: 0.9880
# Epoch 87/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0534 - accuracy: 0.9900
# Epoch 88/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9920
# Epoch 89/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9900
# Epoch 90/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9920
# Epoch 91/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9900
# Epoch 92/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0462 - accuracy: 0.9920
# Epoch 93/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9940
# Epoch 94/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9900
# Epoch 95/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9940
# Epoch 96/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 0.9920
# Epoch 97/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9920
# Epoch 98/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9940
# Epoch 99/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9920
# Epoch 100/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9940

# %%
# plot the cost. use history.history['loss']
plt.plot(range(1, len(history['loss']) + 1),history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Training Cost')

plt.show()

# %% [markdown]
# ### Plot the decision boundary

# %%
# A function for plotting decision regions
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

def plot_decision_regions(X, y, classifier, resolution=0.02):

    # setup marker generator and color map
    markers = ('o', 'x', 's', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, c=colors[idx], marker=markers[idx], label=cl)

# %%
# plot decision boundary of the model
plot_decision_regions(X, y, classifier=model)

plt.xlabel('x1')
plt.ylabel('x2')
plt.legend(loc='upper left')
plt.show()
# Out:
# 1673/1673 [==============================] - 3s 2ms/step

# %% [markdown]
# ---

# %% [markdown]
# # Quiz 2 : CIFAR-10 Image Classification using DNN
# - Dataset : CIFAR-10
#    - 32 x 32 x 3 color images (R, G, B)
#    - 10 classes
#
#
# 1. Load the dataset
# 2. Build the DNN model for image classification using Keras
#    - Use 2 hidden layers of 128 neurons each with ReLU activation
# 3. Train the model with Adam optimizer
# 4. Evaluate the model
# 5. Classify test images [1] ~ [10], and show the results

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and prepare the CIFAR-10 dataset
# - 32 x 32 x 3 color images
# - 10 classes
# - 50000 traning data, 10000 test data

# %%
# load CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
# check the shape of train and test dataset
X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
# check the labels of train data 0 ~ 4
y_train[:5]
# Out:
# array([[6],
#        [9],
#        [9],
#        [4],
#        [1]], dtype=uint8)

# %%
# class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# show first 25 train images and labels
plt.figure(figsize=(8,8))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i][0]])
plt.show()

# %% [markdown]
# ### Build DNN model with Keras - Sequential API

# %%
# build the model
# input shape is (32, 32, 3)
# 1 flatten layer, 2 dense layers with 128 outputs and relu activation function
# 1 dense layer with 10 outputs and softmax activation function
model = models.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),
    layers.Dense(128, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# compile the model with adam optimizer and sparse categorical crossentropy loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# display the model
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 3072)              0
#
#  dense_53 (Dense)            (None, 128)               393344
#
#  dense_54 (Dense)            (None, 128)               16512
#
#  dense_55 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 411146 (1.57 MB)
# Trainable params: 411146 (1.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
# train the model. upto 100 epochs, batch size 128. record history
history = model.fit(X_train, y_train, epochs=100, batch_size=128, verbose=1)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 2s 4ms/step - loss: 1.8922 - accuracy: 0.3163
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 1.7009 - accuracy: 0.3920
# Epoch 3/100
# 391/391 [==============================] - 2s 4ms/step - loss: 1.6216 - accuracy: 0.4218
# Epoch 4/100
# 391/391 [==============================] - 2s 5ms/step - loss: 1.5635 - accuracy: 0.4451
# Epoch 5/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.5243 - accuracy: 0.4569
# Epoch 6/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.5002 - accuracy: 0.4670
# Epoch 7/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.4708 - accuracy: 0.4771
# Epoch 8/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.4550 - accuracy: 0.4842
# Epoch 9/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.4310 - accuracy: 0.4919
# Epoch 10/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.4182 - accuracy: 0.4964
# Epoch 11/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.4006 - accuracy: 0.5033
# Epoch 12/100
# 391/391 [==============================] - 2s 5ms/step - loss: 1.3870 - accuracy: 0.5064
# Epoch 13/100
# 391/391 [==============================] - 2s 5ms/step - loss: 1.3725 - accuracy: 0.5129
# Epoch 14/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.3647 - accuracy: 0.5147
# Epoch 15/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.3597 - accuracy: 0.5171
# Epoch 16/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.3496 - accuracy: 0.5188
# Epoch 17/100
# 391/391 [==============================] - 2s 4ms/step - loss: 1.3313 - accuracy: 0.5254
# Epoch 18/100
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3292 - accuracy: 0.5278
# Epoch 19/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3180 - accuracy: 0.5316
# Epoch 20/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3091 - accuracy: 0.5347
# Epoch 21/100
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2999 - accuracy: 0.5394
# Epoch 22/100
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2904 - accuracy: 0.5411
# Epoch 23/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2808 - accuracy: 0.5434
# Epoch 24/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.2784 - accuracy: 0.5463
# Epoch 25/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2692 - accuracy: 0.5465
# Epoch 26/100
# 391/391 [==============================] - 2s 5ms/step - loss: 1.2622 - accuracy: 0.5515
# Epoch 27/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.2541 - accuracy: 0.5551
# Epoch 28/100
# 391/391 [==============================] - 2s 5ms/step - loss: 1.2535 - accuracy: 0.5559
# Epoch 29/100
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2418 - accuracy: 0.5577
# Epoch 90/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0601 - accuracy: 0.6229
# Epoch 91/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0599 - accuracy: 0.6224
# Epoch 93/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0580 - accuracy: 0.6207
# Epoch 94/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0487 - accuracy: 0.6279
# Epoch 95/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0615 - accuracy: 0.6233
# Epoch 96/100
# 391/391 [==============================] - 2s 5ms/step - loss: 1.0485 - accuracy: 0.6259
# Epoch 97/100
# 391/391 [==============================] - 2s 4ms/step - loss: 1.0533 - accuracy: 0.6236
# Epoch 98/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0435 - accuracy: 0.6306
# Epoch 99/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0469 - accuracy: 0.6250
# Epoch 100/100
# 391/391 [==============================] - 1s 4ms/step - loss: 1.0507 - accuracy: 0.6260

# %% [markdown]
# ### Evaluate the model

# %%
# evaluate the model with training data (training accuracy needs to be > 60%)

model.evaluate(X_train, y_train, verbose=2)
# Out:
# 1563/1563 - 3s - loss: 1.0596 - accuracy: 0.6240 - 3s/epoch - 2ms/step
# [1.059583306312561, 0.6240400075912476]

# %%
# evaluate the model with test data (testing accuracy needs to be > 47%)

model.evaluate(X_test, y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 1.5550 - accuracy: 0.4967 - 591ms/epoch - 2ms/step
# [1.5549625158309937, 0.4966999888420105]

# %%
# plot the loss
plt.plot(history.epoch, history.history['loss'])

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Classify test images

# %%
# get predictions of test data 0. need reshape to (1, 32, 32, 3)
predictions = model.predict(X_test[0].reshape(1, 32, 32, 3))
predictions
# Out:
# 1/1 [==============================] - 0s 55ms/step
# array([[0.06821772, 0.06187496, 0.00747134, 0.10658647, 0.34317803,
#         0.34762663, 0.00124607, 0.01607155, 0.04476573, 0.00296153]],
#       dtype=float32)

# %%
import numpy as np

# show the classification result of test images 1 ~ 9
for i in range(1, 10):
    plt.figure(figsize=(1,1))
    plt.imshow(X_test[i], cmap=plt.cm.binary)
    plt.show()

    prediction = model.predict(X_test)
    y_predict = np.argmax(prediction[i])
    print('True lable = %s' % class_names[y_test[i][0]])
    print('Predicted = %s' % class_names[y_predict])
# Out:
# 313/313 [==============================] - 1s 3ms/step
# True lable = ship
# Predicted = ship
# 313/313 [==============================] - 1s 4ms/step
# True lable = ship
# Predicted = airplane
# 313/313 [==============================] - 1s 2ms/step
# True lable = airplane
# Predicted = ship
# 313/313 [==============================] - 1s 2ms/step
# True lable = frog
# Predicted = deer
# 313/313 [==============================] - 1s 2ms/step
# True lable = frog
# Predicted = frog
# 313/313 [==============================] - 1s 2ms/step
# True lable = automobile
# Predicted = automobile
# 313/313 [==============================] - 1s 2ms/step
# True lable = frog
# Predicted = frog
# 313/313 [==============================] - 1s 2ms/step
# True lable = cat
# Predicted = deer
# 313/313 [==============================] - 1s 2ms/step
# True lable = automobile
# Predicted = automobile
